# %% [markdown]
# <a href="https://colab.research.google.com/github/psvprasad2003/Python-Foundation-Course/blob/PRASAD_WIP_BRANCH/Brief_YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics supervision opencv-python -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 24.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 6.4 MB/s eta 0:00:00

# %%
import numpy as np
import supervision as sv
from ultralytics import YOLO
import cv2
import os
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
## Here I use the built-in GROCERY_STORE video from supervision.
#You can replace it later with your own path.
from supervision.assets import VideoAssets, download_assets
from ultralytics import YOLO  # Added this line to fix NameError

# load a small YOLO model
model = YOLO("yolov8n.pt")  # or any other YOLOv8/YOLO11 model

# input and output video paths
source_path = download_assets(VideoAssets.GROCERY_STORE)
target_path = "grocery_polygon_output.mp4"

# grab video info (width, height, fps, etc.)
video_info = sv.VideoInfo.from_video_path(source_path)
print(video_info)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 314.2MB/s 0.0s
# [2026-06-07 04:15:07] [INFO] supervision.assets.downloader - Downloading grocery-store.mp4 assets
#   0%|          | 0/103282086 [00:00<?, ?it/s]
# VideoInfo(width=3840, height=2160, fps=29.97002997002997, total_frames=1002)

# %%
# polygon vertices in image coordinates [x, y]
polygon = np.array([
    [1725, 1550],
    [2725, 1550],
    [3500, 2160],
    [1250, 2160]
])

# create the polygon zone object
zone = sv.PolygonZone(polygon=polygon)

# visual annotators
box_annotator = sv.BoxAnnotator(thickness=2)
label_annotator = sv.LabelAnnotator(text_thickness=1, text_scale=0.5)

zone_annotator = sv.PolygonZoneAnnotator(
    zone=zone,
    color=sv.Color.WHITE,
    thickness=3,
    text_thickness=1,
    text_scale=0.6
)

# %%
def process_frame(frame, frame_idx):
    # 1) run YOLO detection
    results = model(frame, imgsz=1280)[0]
    detections = sv.Detections.from_ultralytics(results)

    # 2) (optional) keep only "person" class, usually id 0 in COCO
    detections = detections[detections.class_id == 0]

    # 3) update polygon zone (counts how many detections are inside)
    zone.trigger(detections=detections)

    # 4) build labels: "person 0.87", etc.
    labels = [
        f"{model.names[class_id]} {confidence:0.2f}"
        for _, _, confidence, class_id, _, _ in detections
    ]

    # 5) draw boxes, labels, and polygon zone overlay
    frame = box_annotator.annotate(scene=frame, detections=detections)
    frame = label_annotator.annotate(scene=frame, detections=detections, labels=labels)
    frame = zone_annotator.annotate(scene=frame)

    return frame

# %%
sv.process_video(
    source_path=source_path,
    target_path=target_path,
    callback=process_frame
)

print("Done! Saved:", target_path)
# Out:
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 77.1ms
# Speed: 19.8ms preprocess, 77.1ms inference, 34.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 8.7ms
# Speed: 17.6ms preprocess, 8.7ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 8.7ms
# Speed: 14.5ms preprocess, 8.7ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 7.9ms
# Speed: 14.3ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 8.1ms
# Speed: 14.7ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 8.0ms
# Speed: 14.5ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 7.9ms
# Speed: 14.4ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 7.7ms
# Speed: 14.1ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 8.1ms
# Speed: 8.3ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 12.3ms
# Speed: 12.5ms preprocess, 12.3ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 7.7ms
# Speed: 10.6ms preprocess, 7.7ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 8.1ms
# Speed: 8.0ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 10.7ms
# Speed: 12.0ms preprocess, 10.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 7.9ms
# Speed: 8.3ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 7.7ms
# Speed: 8.8ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 7.6ms
# Speed: 8.3ms preprocess, 7.6ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 7.9ms
# Speed: 8.3ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 7.7ms
# Speed: 8.2ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 14.4ms
# Speed: 12.5ms preprocess, 14.4ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 9.4ms
# Speed: 11.9ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 7.9ms
# Speed: 8.7ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 7.6ms
# Speed: 8.1ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 11.7ms
# Speed: 12.0ms preprocess, 11.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 7
ms preprocess, 8.7ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 11.9ms
# Speed: 11.2ms preprocess, 11.9ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.9ms
# Speed: 7.9ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.9ms
# Speed: 8.2ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 8.3ms
# Speed: 7.6ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 skateboard, 1 bottle, 1 refrigerator, 8.2ms
# Speed: 7.9ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 10.0ms
# Speed: 11.1ms preprocess, 10.0ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 skateboard, 1 bottle, 1 cell phone, 1 refrigerator, 10.0ms
# Speed: 10.7ms preprocess, 10.0ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 car, 1 bottle, 1 refrigerator, 9.9ms
# Speed: 10.8ms preprocess, 9.9ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 10.0ms
# Speed: 10.7ms preprocess, 10.0ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 10.3ms
# Speed: 10.8ms preprocess, 10.3ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 refrigerator, 10.1ms
# Speed: 10.8ms preprocess, 10.1ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 2 refrigerators, 10.0ms
# Speed: 10.6ms preprocess, 10.0ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 10.0ms
# Speed: 11.1ms preprocess, 10.0ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.9ms
# Speed: 8.3ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 11.7ms
# Speed: 11.1ms preprocess, 11.7ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 skateboard, 1 bottle, 1 refrigerator, 8.4ms
# Speed: 8.2ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.8ms
# Speed: 11.3ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 refrigerator, 7.8ms
# Speed: 11.6ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 refrigerator, 7.9ms
# Speed: 7.8ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 8.1ms
# Speed: 11.3ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 8.8ms
# Speed: 7.7ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 refrigerator, 7.7ms
# Speed: 8.2ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.9ms
# Speed: 7.8ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 refrigerator, 7.8ms
# Speed: 9.0ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 refrigerator, 7.7ms
# Speed: 8.2ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 11.7ms
# Speed: 10.9ms preprocess, 11.7ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 8.5ms
# Speed: 8.1ms preprocess, 8.5ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 11.8ms
# Speed: 10.9ms preprocess, 11.8ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 7.8ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 cell phone, 1 refrigerator, 7.9ms
# Speed: 8.0ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.2ms
# Speed: 8.2ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 9.8ms
# Speed: 9.6ms preprocess, 9.8ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 dining table, 1 refrigerator, 8.3ms
# Speed: 7.8ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 8.1ms
# Speed: 7.7ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.7ms
# Speed: 7.7ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 2 refrigerators, 8.0ms
# Speed: 7.8ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 2 refrigerators, 7.7ms
# Speed: 8.1ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 dining table, 2 refrigerators, 7.9ms
# Speed: 7.6ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 2 refrigerators, 8.0ms
# Speed: 7.7ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 10.2ms
# Speed: 10.7ms preprocess, 10.2ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 2 refrigerators, 10.0ms
# Speed: 10.9ms preprocess, 10.0ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 2 refrigerators, 10.1ms
# Speed: 10.7ms preprocess, 10.1ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 10.0ms
# Speed: 10.8ms preprocess, 10.0ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 8.2ms
# Speed: 8.3ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.9ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.7ms
# Speed: 7.5ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 7.7ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 8.7ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 8.2ms
# Speed: 8.3ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.8ms
# Speed: 7.7ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.2ms
# Speed: 8.1ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.6ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 umbrella, 2 bottles, 1 refrigerator, 8.1ms
# Speed: 7.7ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.1ms
# Speed: 8.1ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 7.5ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.4ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 bottles, 1 refrigerator, 8.3ms
# Speed: 7.6ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.5ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.2ms
# Speed: 7.9ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.9ms
# Speed: 7.7ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.6ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 8.0ms
# Speed: 7.3ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 8.0ms
# Speed: 7.4ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.9ms
# Speed: 7.8ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 bottles, 1 refrigerator, 8.1ms
# Speed: 7.9ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 bottles, 1 refrigerator, 8.0ms
# Speed: 8.3ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 3 bottles, 1 refrigerator, 7.8ms
# Speed: 7.3ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 8.1ms
# Speed: 7.5ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.8ms
# Speed: 7.5ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.8ms
# Speed: 7.4ms preprocess, 7.8ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.9ms
# Speed: 7.9ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.9ms
# Speed: 8.0ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 8.3ms
# Speed: 7.6ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.7ms
# Speed: 7.6ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.7ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 7.7ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.7ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 7.4ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 (no detections), 7.9ms
# Speed: 7.4ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 736, 1280)
# Done! Saved: grocery_polygon_output.mp4

# %%
def process_video_short(source, target, max_frames=300):
    cap = cv2.VideoCapture(source)
    width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps    = cap.get(cv2.CAP_PROP_FPS)

    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out = cv2.VideoWriter(target, fourcc, fps, (width, height))

    frame_idx = 0
    while True:
        ret, frame = cap.read()
        if not ret or frame_idx >= max_frames:
            break

        frame = process_frame(frame, frame_idx)
        out.write(frame)
        frame_idx += 1

    cap.release()
    out.release()
    print(f"Short video saved to: {target}")

process_video_short(source_path, "grocery_polygon_output_short.mp4", max_frames=300)
# Out:
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 9.1ms
# Speed: 8.3ms preprocess, 9.1ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 8.2ms
# Speed: 7.6ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 7.9ms
# Speed: 7.4ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 8.0ms
# Speed: 7.5ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 8.2ms
# Speed: 7.4ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 8.1ms
# Speed: 7.4ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 8.1ms
# Speed: 7.6ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 8.1ms
# Speed: 7.3ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 8.0ms
# Speed: 7.6ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 11.9ms
# Speed: 11.0ms preprocess, 11.9ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 8.1ms
# Speed: 7.4ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 7.9ms
# Speed: 7.3ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 8.2ms
# Speed: 7.6ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 7.9ms
# Speed: 7.2ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 8.1ms
# Speed: 7.3ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 8.0ms
# Speed: 7.6ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 8.0ms
# Speed: 7.4ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 8.0ms
# Speed: 7.3ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 8.1ms
# Speed: 7.3ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 8.0ms
# Speed: 7.5ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 8.6ms
# Speed: 7.2ms preprocess, 8.6ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 12.2ms
# Speed: 10.9ms preprocess, 12.2ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 7.9ms
# Speed: 7.2ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 8.0ms
# Speed: 7.4ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 8.0ms
# Speed: 7.6ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 8.2ms
# Speed: 11.9ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 8.2ms
# Speed: 7.5ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 chair, 1 refrigerator, 8.1ms
# Speed: 7.7ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 chair, 1 refrigerator, 8.1ms
# Speed: 7.4ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 chair, 2 refrigerators, 8.0ms
# Speed: 7.3ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 chair, 1 refrigerator, 8.1ms
# Speed: 7.5ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 4 bottles, 1 chair, 2 refrigerators, 8.2ms
# Speed: 7.6ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 8.0ms
# Speed: 7.5ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 4 bottles, 1 chair, 1 refrigerator, 8.1ms
# Speed: 7.6ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 chair, 1 refrigerator, 8.0ms
# Speed: 7.3ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 chair, 1 refrigerator, 8.4ms
# Speed: 7.7ms preprocess, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 chair, 1 refrigerator, 8.0ms
# Speed: 7.6ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 4 bottles, 1 chair, 1 refrigerator, 8.0ms
# Speed: 7.4ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 chair, 1 refrigerator, 8.2ms
# Speed: 7.8ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 chair, 1 refrigerator, 8.1ms
# Speed: 7.7ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 7.9ms
# Speed: 7.4ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 8.4ms
# Speed: 7.9ms preprocess, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 chair, 1 refrigerator, 7.9ms
# Speed: 7.7ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 chair, 1 refrigerator, 8.0ms
# Speed: 7.6ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 3 bottles, 1 chair, 1 refrigerator, 7.9ms
# Speed: 7.7ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 2 bottles, 1 chair, 1 refrigerator, 8.2ms
# Speed: 7.6ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 2 bottles, 1 chair, 1 refrigerator, 8.1ms
# Speed: 7.7ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 3 bottles, 1 chair, 1 refrigerator, 8.0ms
# Speed: 7.6ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 2 bottles, 1 chair, 1 refrigerator, 8.1ms
# Speed: 7.6ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 7.7ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 7.7ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 7.7ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.1ms
# Speed: 7.6ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 7.5ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 3 bottles, 1 refrigerator, 8.2ms
# Speed: 7.7ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 3 bottles, 1 refrigerator, 8.1ms
# Speed: 7.6ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 7.6ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 3 bottles, 1 refrigerator, 8.3ms
# Speed: 7.8ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 7.7ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 7.8ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.6ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 7.7ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 8.0ms
# Speed: 7.7ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 7.7ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 7.7ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.2ms
# Speed: 7.5ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.2ms
# Speed: 8.7ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.1ms
# Speed: 7.6ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 8.1ms
# Speed: 7.8ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 8.0ms
# Speed: 7.6ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 4 bottles, 1 refrigerator, 7.9ms
# Speed: 7.3ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.9ms
# Speed: 7.3ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 3 bottles, 1 refrigerator, 8.1ms
# Speed: 7.7ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 3 bottles, 1 refrigerator, 7.8ms
# Speed: 7.4ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 4 bottles, 1 refrigerator, 8.0ms
# Speed: 7.4ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 4 bottles, 1 refrigerator, 7.8ms
# Speed: 7.5ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.8ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 4 bottles, 1 refrigerator, 8.0ms
# Speed: 7.5ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 4 bottles, 1 refrigerator, 7.9ms
# Speed: 7.9ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.8ms
# Speed: 7.4ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 4 bottles, 1 refrigerator, 8.2ms
# Speed: 7.3ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 8.3ms
# Speed: 7.7ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 8.0ms
# Speed: 7.6ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.8ms
# Speed: 7.6ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.7ms
# Speed: 7.5ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.9ms
# Speed: 7.5ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.5ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.7ms
# Speed: 7.5ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.4ms
# Speed: 7.4ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.8ms
# Speed: 7.8ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.2ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.7ms
# Speed: 7.3ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.7ms
# Speed: 7.2ms preprocess, 7.7ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 8.1ms
# Speed: 7.9ms preprocess, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.7ms
# Speed: 7.4ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.8ms
# Speed: 7.4ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 tv, 1 refrigerator, 7.8ms
# Speed: 7.3ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.5ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.7ms
# Speed: 7.1ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.2ms
# Speed: 7.6ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.7ms
# Speed: 7.5ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.8ms
# Speed: 7.5ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.8ms
# Speed: 7.3ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.9ms
# Speed: 7.4ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.3ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.8ms
# Speed: 7.5ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.5ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.7ms
# Speed: 7.7ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.1ms
# Speed: 8.2ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.1ms
# Speed: 7.6ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.8ms
# Speed: 7.4ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 8.0ms
# Speed: 7.5ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 tv, 1 refrigerator, 7.9ms
# Speed: 7.3ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.9ms
# Speed: 8.1ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.1ms
# Speed: 7.7ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.3ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.9ms
# Speed: 7.3ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 8.3ms
# Speed: 7.8ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.4ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.8ms
# Speed: 7.2ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 8.1ms
# Speed: 7.5ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.3ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.1ms
# Speed: 7.4ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.2ms
# Speed: 7.6ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.4ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.9ms
# Speed: 7.3ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 8.0ms
# Speed: 7.6ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.9ms
# Speed: 7.5ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.9ms
# Speed: 7.2ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 11.7ms
# Speed: 11.0ms preprocess, 11.7ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 tv, 1 refrigerator, 8.0ms
# Speed: 7.3ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 11.4ms
# Speed: 11.1ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.8ms
# Speed: 7.4ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 12.0ms
# Speed: 10.9ms preprocess, 12.0ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.9ms
# Speed: 7.5ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.8ms
# Speed: 7.3ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 11.9ms
# Speed: 10.9ms preprocess, 11.9ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.7ms
# Speed: 7.2ms preprocess, 7.7ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.7ms
# Speed: 7.2ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 7.7ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.7ms
# Speed: 7.2ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.8ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.3ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.3ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.8ms
# Speed: 7.4ms preprocess, 7.8ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 11.8ms
# Speed: 10.8ms preprocess, 11.8ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.4ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.4ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 11.4ms
# Speed: 11.1ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.9ms
# Speed: 7.4ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.2ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.9ms
# Speed: 7.6ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.8ms
# Speed: 7.6ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 7.8ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.3ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.8ms
# Speed: 7.4ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.9ms
# Speed: 7.3ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 8.0ms
# Speed: 7.4ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.3ms preprocess, 7.8ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.8ms
# Speed: 7.2ms preprocess, 7.8ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.9ms
# Speed: 7.4ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.2ms
# Speed: 7.6ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 8.3ms
# Speed: 7.3ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.8ms
# Speed: 7.5ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.4ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.8ms
# Speed: 7.2ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.3ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.8ms
# Speed: 7.4ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.9ms
# Speed: 7.4ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.9ms
# Speed: 7.2ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.4ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.3ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 8.0ms
# Speed: 7.4ms preprocess, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.8ms
# Speed: 7.6ms preprocess, 7.8ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 8.0ms
# Speed: 7.4ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.3ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.2ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 7.2ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.7ms
# Speed: 7.3ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.3ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.7ms
# Speed: 7.3ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 10.3ms
# Speed: 11.0ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.8ms
# Speed: 7.5ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.6ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 11.7ms
# Speed: 10.8ms preprocess, 11.7ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.3ms
# Speed: 9.9ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bench, 3 bottles, 1 refrigerator, 11.8ms
# Speed: 11.0ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bench, 3 bottles, 1 refrigerator, 7.8ms
# Speed: 7.4ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.7ms
# Speed: 7.5ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.7ms
# Speed: 7.3ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bench, 2 bottles, 1 refrigerator, 7.7ms
# Speed: 7.6ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.5ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 2 bottles, 1 refrigerator, 7.7ms
# Speed: 7.0ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.7ms
# Speed: 7.4ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 7.5ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.4ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.6ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.6ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.8ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 12.0ms
# Speed: 11.0ms preprocess, 12.0ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.9ms
# Speed: 8.0ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 bottle, 1 refrigerator, 7.8ms
# Speed: 7.5ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.7ms
# Speed: 7.4ms preprocess, 7.7ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.9ms
# Speed: 7.5ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.4ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 10.1ms
# Speed: 10.6ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.1ms
# Speed: 7.3ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.7ms
# Speed: 7.4ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 11.7ms
# Speed: 10.9ms preprocess, 11.7ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.3ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 4 bottles, 1 refrigerator, 11.2ms
# Speed: 10.9ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.7ms
# Speed: 7.4ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.7ms
# Speed: 7.8ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.5ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.7ms
# Speed: 7.5ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 8.1ms
# Speed: 7.6ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 tv, 1 refrigerator, 7.7ms
# Speed: 7.2ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 tv, 1 refrigerator, 7.8ms
# Speed: 7.7ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.8ms
# Speed: 7.5ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 tv, 1 refrigerator, 7.8ms
# Speed: 7.8ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 tv, 1 refrigerator, 11.6ms
# Speed: 10.8ms preprocess, 11.6ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 bottle, 1 tv, 1 refrigerator, 7.9ms
# Speed: 7.3ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.8ms
# Speed: 7.5ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 tv, 1 refrigerator, 8.0ms
# Speed: 7.7ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 2 bottles, 1 dining table, 1 refrigerator, 8.9ms
# Speed: 8.2ms preprocess, 8.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 bottle, 1 dining table, 1 refrigerator, 7.9ms
# Speed: 7.8ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 bottle, 1 dining table, 1 refrigerator, 7.8ms
# Speed: 7.7ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 3 bottles, 1 refrigerator, 7.8ms
# Speed: 8.0ms preprocess, 7.8ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 dining table, 1 refrigerator, 11.9ms
# Speed: 11.0ms preprocess, 11.9ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 dining table, 1 refrigerator, 7.9ms
# Speed: 7.5ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 dining table, 1 refrigerator, 7.9ms
# Speed: 7.6ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 dining table, 1 refrigerator, 8.0ms
# Speed: 7.4ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.7ms
# Speed: 7.5ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.5ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.7ms
# Speed: 7.4ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.7ms
# Speed: 7.6ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.7ms
# Speed: 7.7ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.8ms
# Speed: 7.4ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 dining table, 1 refrigerator, 7.8ms
# Speed: 7.5ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 dining table, 1 refrigerator, 8.0ms
# Speed: 7.5ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.7ms
# Speed: 7.4ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.8ms
# Speed: 7.2ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 bottle, 1 refrigerator, 7.8ms
# Speed: 7.4ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 dining table, 1 refrigerator, 7.8ms
# Speed: 7.3ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 dining table, 1 refrigerator, 7.9ms
# Speed: 7.2ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.7ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 2 bottles, 1 dining table, 1 refrigerator, 7.7ms
# Speed: 7.5ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 dining table, 1 refrigerator, 7.8ms
# Speed: 7.5ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 3 bottles, 1 dining table, 1 refrigerator, 7.8ms
# Speed: 7.9ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 dining table, 1 refrigerator, 7.8ms
# Speed: 7.4ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 dining table, 1 refrigerator, 7.8ms
# Speed: 7.7ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 dining table, 1 refrigerator, 7.9ms
# Speed: 7.5ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 7.8ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 2 bottles, 1 dining table, 1 refrigerator, 7.8ms
# Speed: 7.6ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 3 bottles, 1 dining table, 1 refrigerator, 12.0ms
# Speed: 10.8ms preprocess, 12.0ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.3ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.8ms
# Speed: 7.2ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 bottle, 1 refrigerator, 7.9ms
# Speed: 7.7ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 bottle, 1 refrigerator, 7.9ms
# Speed: 7.9ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 bottle, 1 refrigerator, 7.9ms
# Speed: 7.7ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 bottle, 1 dining table, 1 refrigerator, 7.8ms
# Speed: 7.4ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 bottle, 1 refrigerator, 7.8ms
# Speed: 7.8ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 bottle, 1 refrigerator, 7.7ms
# Speed: 7.7ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 bottle, 1 refrigerator, 7.7ms
# Speed: 7.7ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 bottle, 1 refrigerator, 7.8ms
# Speed: 7.5ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.7ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 2 bottles, 1 refrigerator, 8.0ms
# Speed: 7.6ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 bottle, 1 dining table, 1 refrigerator, 7.8ms
# Speed: 7.3ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 1 bottle, 1 refrigerator, 8.2ms
# Speed: 7.4ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 8.0ms
# Speed: 7.5ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 dining table, 1 refrigerator, 7.8ms
# Speed: 7.3ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 dining table, 1 refrigerator, 7.8ms
# Speed: 7.5ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 dining table, 1 refrigerator, 7.8ms
# Speed: 7.4ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 12.0ms
# Speed: 11.0ms preprocess, 12.0ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.8ms
# Speed: 7.5ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 dining table, 1 refrigerator, 7.7ms
# Speed: 7.7ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 dining table, 1 refrigerator, 7.7ms
# Speed: 7.4ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 dining table, 1 refrigerator, 7.7ms
# Speed: 7.5ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 dining table, 1 refrigerator, 12.1ms
# Speed: 11.0ms preprocess, 12.1ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 dining table, 1 refrigerator, 7.8ms
# Speed: 7.5ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 4 bottles, 1 dining table, 1 refrigerator, 7.7ms
# Speed: 7.6ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 8.0ms
# Speed: 7.9ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.3ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.8ms
# Speed: 7.2ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 9.4ms
# Speed: 7.9ms preprocess, 9.4ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.6ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 7.9ms
# Speed: 7.6ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 1 bottle, 1 refrigerator, 8.3ms
# Speed: 7.9ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 dining table, 1 refrigerator, 8.0ms
# Speed: 7.2ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 refrigerator, 7.9ms
# Speed: 7.2ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.9ms
# Speed: 8.0ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 4 bottles, 1 refrigerator, 7.8ms
# Speed: 7.7ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 3 bottles, 1 refrigerator, 7.8ms
# Speed: 7.2ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 5 bottles, 1 refrigerator, 7.8ms
# Speed: 7.6ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 5 bottles, 1 dining table, 1 refrigerator, 7.9ms
# Speed: 7.6ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 6 bottles, 1 orange, 1 refrigerator, 7.9ms
# Speed: 7.5ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 4 bottles, 1 orange, 1 refrigerator, 8.1ms
# Speed: 8.0ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 1 person, 2 bottles, 1 orange, 1 refrigerator, 7.8ms
# Speed: 7.8ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 4 bottles, 1 refrigerator, 7.8ms
# Speed: 7.4ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
#
# 0: 736x1280 2 persons, 2 bottles, 1 orange, 1 refrigerator, 8.0ms
# Speed: 7.5ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
# Short video saved to: grocery_polygon_output_short.mp4

# %%
from google.colab import files

files.download('/content/grocery_polygon_output.mp4')

# %%
from google.colab import files

files.download('/content/grocery_polygon_output_short.mp4')

# %%
from google.colab import files

files.download('/content/grocery-store.mp4')
